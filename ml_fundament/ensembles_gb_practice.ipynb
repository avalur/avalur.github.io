# %% [markdown]
# <center><img src="./images/nup_logo_dark.jpeg" width=300 style="display: inline-block;"></center>
#
# ## Fundamentals of Machine Learning
# ### Ensembles, gradient boosting and random forest
#
# <br />

# %% [markdown]
# ### Import libraries and create dataset

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, 
                           n_redundant=5, random_state=42)

# %%
X.shape
# Out:
# (1000, 20)

# %%
pd.Series.value_counts(y)
# Out:
# 0    502
# 1    498
# Name: count, dtype: int64

# %%
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold

def eval_classifier(clf):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=43)
    n_scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
    return np.mean(n_scores), np.std(n_scores)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

results_accuracy = pd.DataFrame(0.0,
                                columns=['No composition', 'Dummy', 'Bagging', 'Bagging_mf', 'AdaBoost'],
                                index=['DTC', 'DTC-1', 'LR', 'SVC'])

# %%
acc_mean, acc_std = eval_classifier(DecisionTreeClassifier())

results_accuracy.loc['DTC', 'No composition'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.79, 0.05

# %%
acc_mean, acc_std = eval_classifier(DecisionTreeClassifier(max_depth=1))

results_accuracy.loc['DTC-1', 'No composition'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.68, 0.04

# %%
acc_mean, acc_std = eval_classifier(LogisticRegression())

results_accuracy.loc['LR', 'No composition'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.81, 0.03

# %%
acc_mean, acc_std = eval_classifier(SVC(probability=True))

results_accuracy.loc['SVC', 'No composition'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.94, 0.02

# %% [markdown]
# ### Dummy

# %% [markdown]
# First, let's implement our simplest assembling method.
#
# The idea is very simple: we will just train the classifier several times and average the answer:
# $$c(x) = \frac{1}{n}\sum_{i=1}^n c_i(x)$$

# %%
from sklearn import base

class DummyEnsemble(object):
    def __init__(self, base_estimator, n_estimators=10):
        self.n_estimators = n_estimators
        self.base_estimator = base_estimator            
        self._bs = [base.clone(self.base_estimator) for _ in range(self.n_estimators)]
        
    def get_params(self, deep=True):
        return {'n_estimators': self.n_estimators, 
                'base_estimator': self.base_estimator}
        
    def fit(self, X, Y):
        for b in self._bs:
            b.fit(X, Y)
            
    def predict(self, X):
        probas = self.predict_proba(X)
        return np.argmax(probas, axis=1)
    
    def predict_proba(self, X):
        return np.mean([b.predict_proba(X) for b in self._bs], axis=0)

# %%
acc_mean, acc_std = eval_classifier(DummyEnsemble(DecisionTreeClassifier(), n_estimators=10))

results_accuracy.loc['DTC', 'Dummy'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.80, 0.04

# %%
acc_mean, acc_std = eval_classifier(DummyEnsemble(DecisionTreeClassifier(max_depth=1)))

results_accuracy.loc['DTC-1', 'Dummy'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.68, 0.04

# %%
acc_mean, acc_std = eval_classifier(DummyEnsemble(LogisticRegression()))

results_accuracy.loc['LR', 'Dummy'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.81, 0.03

# %%
acc_mean, acc_std = eval_classifier(DummyEnsemble(SVC(probability=True)))

results_accuracy.loc['SVC', 'Dummy'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.94, 0.02

# %% [markdown]
# **Question 1:** What problems does this method have?

# %%
pd.options.display.float_format = "{:,.2f}".format
results_accuracy
# Out:
#        No composition  Dummy  Bagging  Bagging_mf  AdaBoost
# DTC              0.79   0.80     0.00        0.00      0.00
# DTC-1            0.68   0.68     0.00        0.00      0.00
# LR               0.81   0.81     0.00        0.00      0.00
# SVC              0.94   0.94     0.00        0.00      0.00

# %% [markdown]
# ### Bagging

# %% [markdown]
# A natural modification of the method from the previous point is Bagging.
# In it, we use only part of the data/features to train each subsequent model.

# %%
from sklearn.ensemble import BaggingClassifier

acc_mean, acc_std = eval_classifier(
    BaggingClassifier(DecisionTreeClassifier(), n_estimators=10, 
                      max_samples=1.0, max_features=1.0, 
                      bootstrap=True, bootstrap_features=False))

results_accuracy.loc['DTC', 'Bagging'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.86, 0.04

# %%
acc_mean, acc_std = eval_classifier(
    BaggingClassifier(DecisionTreeClassifier(), n_estimators=10, 
                      max_samples=1.0, max_features=0.8, 
                      bootstrap=True, bootstrap_features=False))

results_accuracy.loc['DTC', 'Bagging_mf'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.88, 0.03

# %%
acc_mean, acc_std = eval_classifier(
    BaggingClassifier(DecisionTreeClassifier(max_depth=1), n_estimators=10, 
                      max_samples=1.0, max_features=1.0, 
                      bootstrap=True, bootstrap_features=False))

results_accuracy.loc['DTC-1', 'Bagging'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.68, 0.04

# %%
acc_mean, acc_std = eval_classifier(
    BaggingClassifier(DecisionTreeClassifier(max_depth=1), n_estimators=10, 
                      max_samples=1.0, max_features=0.8, 
                      bootstrap=True, bootstrap_features=False))

results_accuracy.loc['DTC-1', 'Bagging_mf'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.69, 0.04

# %%
acc_mean, acc_std = eval_classifier(
    BaggingClassifier(LogisticRegression(), n_estimators=10, 
                      max_samples=1.0, max_features=1.0, 
                      bootstrap=True, bootstrap_features=False))

results_accuracy.loc['LR', 'Bagging'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.81, 0.03

# %%
acc_mean, acc_std = eval_classifier(
    BaggingClassifier(LogisticRegression(), n_estimators=10, 
                      max_samples=1.0, max_features=0.8, 
                      bootstrap=True, bootstrap_features=False))

results_accuracy.loc['LR', 'Bagging_mf'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.81, 0.04

# %%
acc_mean, acc_std = eval_classifier(BaggingClassifier(SVC(probability=True)))

results_accuracy.loc['SVC', 'Bagging'] = acc_mean
print(f"{acc_mean:.3f}, {acc_std:.3f}")
# Out:
# 0.937, 0.023

# %%
acc_mean, acc_std = eval_classifier(
    BaggingClassifier(SVC(probability=True), n_estimators=10, 
                      max_samples=1.0, max_features=0.8, 
                      bootstrap=True, bootstrap_features=False))

results_accuracy.loc['SVC', 'Bagging_mf'] = acc_mean
print(f"{acc_mean:.3f}, {acc_std:.3f}")
# Out:
# 0.943, 0.020

# %% [markdown]
# **Question 2:** What are the pros/cons of Bagging compared to the Dummy method?

# %%
results_accuracy
# Out:
#        No composition  Dummy  Bagging  Bagging_mf  AdaBoost
# DTC              0.79   0.80     0.86        0.88      0.00
# DTC-1            0.68   0.68     0.68        0.69      0.00
# LR               0.81   0.81     0.81        0.81      0.00
# SVC              0.94   0.94     0.94        0.94      0.00

# %% [markdown]
# ### AdaBoost

# %% [markdown]
# AdaBoost trains each subsequent classifier on objects where the previous ones make mistakes
# (objects with errors get a higher weight, without errors — lower).

# %%
from sklearn.ensemble import AdaBoostClassifier

acc_mean, acc_std = eval_classifier(
    AdaBoostClassifier(DecisionTreeClassifier(), n_estimators=50, learning_rate=1.0))

results_accuracy.loc['DTC', 'AdaBoost'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.79, 0.05

# %%
acc_mean, acc_std = eval_classifier(
    AdaBoostClassifier(DecisionTreeClassifier(max_depth=1))
)

results_accuracy.loc['DTC-1', 'AdaBoost'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.81, 0.04

# %%
acc_mean, acc_std = eval_classifier(
    AdaBoostClassifier(LogisticRegression())
)

results_accuracy.loc['LR', 'AdaBoost'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.80, 0.04

# %%
acc_mean, acc_std = eval_classifier(
    AdaBoostClassifier(SVC(probability=True))
)

results_accuracy.loc['SVC', 'AdaBoost'] = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.50, 0.00

# %%
def highlight_max(s, props=''):
    # print(s)
    return np.where(s == np.nanmax(s.values), props, '')

results_to_show = results_accuracy.copy()

results_html = (results_to_show.style
                .apply(highlight_max, props='color:white;background-color:green;', axis=1)
                .format('{:.3f}')
                .to_html())

# %%
# Write the HTML file
with open('pretty_results.html', 'w') as f:
    f.write(results_html)

# %%
from IPython.display import HTML, display

display(HTML(results_html))
# Out:
# <style type="text/css">
# #T_34eaf_row0_col3, #T_34eaf_row1_col4, #T_34eaf_row2_col2, #T_34eaf_row3_col3 {
#   color: white;
#   background-color: green;
# }
# </style>
# <table id="T_34eaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34eaf_level0_col0" class="col_heading level0 col0" >No composition</th>
#       <th id="T_34eaf_level0_col1" class="col_heading level0 col1" >Dummy</th>
#       <th id="T_34eaf_level0_col2" class="col_heading level0 col2" >Bagging</th>
#       <th id="T_34eaf_level0_col3" class="col_heading level0 col3" >Bagging_mf</th>
#       <th id="T_34eaf_level0_col4" class="col_heading level0 col4" >AdaBoost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34eaf_level0_row0" class="row_heading level0 row0" >DTC</th>
#       <td id="T_34eaf_row0_col0" class="data row0 col0" >0.790</td>
#       <td id="T_34eaf_row0_col1" class="data row0 col1" >0.797</td>
#       <td id="T_34eaf_row0_col2" class="data row0 col2" >0.865</td>
#       <td id="T_34eaf_row0_col3" class="data row0 col3" >0.881</td>
#       <td id="T_34eaf_row0_col4" class="data row0 col4" >0.786</td>
#     </tr>
#     <tr>
#       <th id="T_34eaf_level0_row1" class="row_heading level0 row1" >DTC-1</th>
#       <td id="T_34eaf_row1_col0" class="data row1 col0" >0.683</td>
#       <td id="T_34eaf_row1_col1" class="data row1 col1" >0.683</td>
#       <td id="T_34eaf_row1_col2" class="data row1 col2" >0.683</td>
#       <td id="T_34eaf_row1_col3" class="data row1 col3" >0.693</td>
#       <td id="T_34eaf_row1_col4" class="data row1 col4" >0.813</td>
#     </tr>
#     <tr>
#       <th id="T_34eaf_level0_row2" class="row_heading level0 row2" >LR</th>
#       <td id="T_34eaf_row2_col0" class="data row2 col0" >0.811</td>
#       <td id="T_34eaf_row2_col1" class="data row2 col1" >0.811</td>
#       <td id="T_34eaf_row2_col2" class="data row2 col2" >0.812</td>
#       <td id="T_34eaf_row2_col3" class="data row2 col3" >0.811</td>
#       <td id="T_34eaf_row2_col4" class="data row2 col4" >0.798</td>
#     </tr>
#     <tr>
#       <th id="T_34eaf_level0_row3" class="row_heading level0 row3" >SVC</th>
#       <td id="T_34eaf_row3_col0" class="data row3 col0" >0.938</td>
#       <td id="T_34eaf_row3_col1" class="data row3 col1" >0.941</td>
#       <td id="T_34eaf_row3_col2" class="data row3 col2" >0.937</td>
#       <td id="T_34eaf_row3_col3" class="data row3 col3" >0.943</td>
#       <td id="T_34eaf_row3_col4" class="data row3 col4" >0.502</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Question 3:** Neither bagging nor boosting provided a noticeable improvement for logistic regression.
# Explain why.

# %% [markdown]
# **Question 4:** Why does AdaBoost perform worse on deep trees?

# %% [markdown]
# **Question 5:** What are the downsides of using AdaBoost + SVC?

# %% [markdown]
# ### GradBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier

acc_mean, acc_std = eval_classifier(GradientBoostingClassifier())

sklearn_gboost = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.90, 0.04

# %% [markdown]
# ### XGBoost

# %% [markdown]
# [Article](https://www.kdd.org/kdd2016/papers/files/rfp0697-chenAemb.pdf)
#
# Pros:
# - Great [documentation](https://xgboost.readthedocs.io/en/latest/)
# - Easily parallelize computations (for example, on Spark)
# - Easy to use with `sklearn` and `numpy` (but with a performance loss)
# - Handling sparse data
# - Pre-sorted blocks, caches, sharding

# %%
import xgboost

acc_mean, acc_std = eval_classifier(xgboost.XGBClassifier(objective='binary:logistic', random_state=42))

xg_boost = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.92, 0.03

# %% [markdown]
# ### LightGBM

# %% [markdown]
# [Article](https://papers.nips.cc/paper/2017/file/6449f44a102fde848669bdd9eb6b76fa-Paper.pdf)
#
# Pros:
# * Good [documentation](https://lightgbm.readthedocs.io/en/latest/Python-API.html)
# * GPU support
# * Fisher's method for working with categorical features
# * Reducing the size of the training sample (GOSS)
# * Combining sparse features (EFB)
#
# Cons:
# * Microsoft has, as always, gone its own way and the interface is not compatible with sklearn/numpy

# %%
import lightgbm as lgb

train_data = lgb.Dataset(X, label=y)

param = {'num_leaves': 31, 
         'objective': 'multiclass', 
         'num_class': 2, 
         'metric': ['multi_logloss']}

num_round = 10
boost = lgb.train(param, train_data, num_boost_round=10)

lg_boost = (boost.predict(X).argmax(axis=-1) == y).mean()

print(f"{lg_boost:.2f}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000359 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 1000, number of used features: 20
# [LightGBM] [Info] Start training from score -0.689155
# [LightGBM] [Info] Start training from score -0.697155
# 0.95

# %% [markdown]
# ### CatBoost

# %% [markdown]
# [Article](https://papers.nips.cc/paper/2018/file/14491b756b3a51daac41c24863285549-Paper.pdf)
#
# Pros:
# * Good [documentation](https://catboost.ai/docs/concepts/python-quickstart.html)
# * GPU support
# * Easy to use with sklearn and numpy
# * More advanced work with categorical features
# * Can be developed in St. Petersburg
#
# Cons:
# * Sometimes performs worse (possibly weaker heuristics), but good with categorical features

# %%
from catboost import CatBoostClassifier

acc_mean, acc_std = eval_classifier(
    CatBoostClassifier(
        iterations=10,
        depth=2,
        learning_rate=1,
        loss_function='Logloss',
        verbose=True, 
        task_type='CPU'))

сat_boost = acc_mean
print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0:	learn: 0.5863056	total: 69.5ms	remaining: 626ms
# 1:	learn: 0.5429305	total: 70.4ms	remaining: 282ms
# 2:	learn: 0.4839598	total: 71.3ms	remaining: 166ms
# 3:	learn: 0.4480620	total: 72.2ms	remaining: 108ms
# 4:	learn: 0.4202819	total: 73.6ms	remaining: 73.6ms
# 5:	learn: 0.3934171	total: 74.5ms	remaining: 49.6ms
# 6:	learn: 0.3659950	total: 75.3ms	remaining: 32.3ms
# 7:	learn: 0.3428333	total: 76.2ms	remaining: 19.1ms
# 8:	learn: 0.3126879	total: 76.8ms	remaining: 8.54ms
# 9:	learn: 0.2958381	total: 78.2ms	remaining: 0us
# 0:	learn: 0.5996266	total: 65.2ms	remaining: 587ms
# 1:	learn: 0.5571886	total: 65.7ms	remaining: 263ms
# 2:	learn: 0.5039877	total: 66.1ms	remaining: 154ms
# 3:	learn: 0.4588837	total: 66.6ms	remaining: 99.9ms
# 4:	learn: 0.4362271	total: 67.4ms	remaining: 67.4ms
# 5:	learn: 0.3917592	total: 68.1ms	remaining: 45.4ms
# 6:	learn: 0.3668400	total: 68.9ms	remaining: 29.5ms
# 7:	learn: 0.3413980	total: 70ms	remaining: 17.5ms
# 8:	learn: 0.3137584	total: 70.5ms	remaining: 7.83ms
# 0:	learn: 0.6032662	total: 472us	remaining: 4.25ms
# 0:	learn: 0.5920428	total: 65.2ms	remaining: 587ms
# 1:	learn: 0.5491389	total: 919us	remaining: 3.68ms
# 9:	learn: 0.3055219	total: 71ms	remaining: 0us
# 1:	learn: 0.5364980	total: 65.7ms	remaining: 263ms
# 0:	learn: 0.5824410	total: 69.1ms	remaining: 622ms
# 2:	learn: 0.5121060	total: 1.37ms	remaining: 3.2ms
# 2:	learn: 0.4821641	total: 66.1ms	remaining: 154ms
# 3:	learn: 0.4729353	total: 1.82ms	remaining: 2.73ms
# 1:	learn: 0.5350100	total: 69.6ms	remaining: 279ms
# 3:	learn: 0.4373357	total: 66.5ms	remaining: 99.8ms
# 4:	learn: 0.4338225	total: 2.27ms	remaining: 2.27ms
# 4:	learn: 0.4155956	total: 67ms	remaining: 67ms
# 2:	learn: 0.4926793	total: 70.3ms	remaining: 164ms
# 5:	learn: 0.4105217	total: 2.71ms	remaining: 1.8ms
# 5:	learn: 0.3957669	total: 67.4ms	remaining: 44.9ms
# 6:	learn: 0.3847444	total: 3.17ms	remaining: 1.36ms
# 3:	learn: 0.4452446	total: 70.9ms	remaining: 106ms
# 0:	learn: 0.5925471	total: 70.7ms	remaining: 636ms
# 7:	learn: 0.3691840	total: 3.63ms	remaining: 907us
# 4:	learn: 0.4245099	total: 71.3ms	remaining: 71.3ms
# 6:	learn: 0.3776205	total: 68.2ms	remaining: 29.2ms
# 8:	learn: 0.3469720	total: 4.07ms	remaining: 452us
# 5:	learn: 0.4046830	total: 71.8ms	remaining: 47.9ms
# 9:	learn: 0.3368895	total: 4.53ms	remaining: 0us
# 6:	learn: 0.3842197	total: 72.2ms	remaining: 31ms
# 1:	learn: 0.5278402	total: 71.9ms	remaining: 288ms
# 7:	learn: 0.3574123	total: 69.2ms	remaining: 17.3ms
# 7:	learn: 0.3628077	total: 72.7ms	remaining: 18.2ms
# 8:	learn: 0.3405313	total: 69.7ms	remaining: 7.75ms
# 8:	learn: 0.3339783	total: 73.1ms	remaining: 8.13ms
# 9:	learn: 0.3241379	total: 70.2ms	remaining: 0us
# 2:	learn: 0.4890202	total: 73.1ms	remaining: 171ms
# 9:	learn: 0.3202711	total: 73.6ms	remaining: 0us
# 0:	learn: 0.5958670	total: 63.7ms	remaining: 573ms
# 3:	learn: 0.4199929	total: 73.7ms	remaining: 110ms
# 4:	learn: 0.3903864	total: 74.1ms	remaining: 74.1ms
# 0:	learn: 0.5906151	total: 65.3ms	remaining: 588ms
# 5:	learn: 0.3608531	total: 74.6ms	remaining: 49.7ms
# 1:	learn: 0.5420130	total: 65.7ms	remaining: 263ms
# 6:	learn: 0.3286970	total: 75ms	remaining: 32.2ms
# 0:	learn: 0.5875380	total: 68.2ms	remaining: 614ms
# 2:	learn: 0.5016539	total: 66.1ms	remaining: 154ms
# 7:	learn: 0.3156023	total: 75.5ms	remaining: 18.9ms
# 1:	learn: 0.5279434	total: 69ms	remaining: 276ms
# 3:	learn: 0.4530937	total: 66.6ms	remaining: 99.9ms
# 8:	learn: 0.2958175	total: 75.9ms	remaining: 8.44ms
# 4:	learn: 0.4245360	total: 67ms	remaining: 67ms
# 9:	learn: 0.2785183	total: 76.4ms	remaining: 0us
# 2:	learn: 0.4835924	total: 69.8ms	remaining: 163ms
# 5:	learn: 0.3984808	total: 67.7ms	remaining: 45.1ms
# 3:	learn: 0.4615509	total: 70.3ms	remaining: 105ms
# 4:	learn: 0.4120885	total: 70.7ms	remaining: 70.7ms
# 6:	learn: 0.3799622	total: 68.4ms	remaining: 29.3ms
# 5:	learn: 0.3883618	total: 71.2ms	remaining: 47.4ms
# 7:	learn: 0.3620905	total: 68.8ms	remaining: 17.2ms
# 6:	learn: 0.3736585	total: 71.6ms	remaining: 30.7ms
# 8:	learn: 0.3392909	total: 69.3ms	remaining: 7.7ms
# 7:	learn: 0.3485491	total: 72ms	remaining: 18ms
# 9:	learn: 0.3207186	total: 69.8ms	remaining: 0us
# 8:	learn: 0.3290695	total: 72.5ms	remaining: 8.05ms
# 9:	learn: 0.3113143	total: 73ms	remaining: 0us
# 0:	learn: 0.5985789	total: 68.8ms	remaining: 619ms
# 0:	learn: 0.5895320	total: 71.3ms	remaining: 642ms
# 1:	learn: 0.5435707	total: 69.8ms	remaining: 279ms
# 1:	learn: 0.5503392	total: 71.8ms	remaining: 287ms
# 2:	learn: 0.5082206	total: 70.3ms	remaining: 164ms
# 3:	learn: 0.4740560	total: 70.8ms	remaining: 106ms
# 2:	learn: 0.5185330	total: 72.8ms	remaining: 170ms
# 4:	learn: 0.4502614	total: 71.2ms	remaining: 71.2ms
# 5:	learn: 0.4274513	total: 71.7ms	remaining: 47.8ms
# 3:	learn: 0.4935014	total: 73.8ms	remaining: 111ms
# 6:	learn: 0.4025519	total: 72.1ms	remaining: 30.9ms
# 1:	learn: 0.5520152	total: 74.3ms	remaining: 297ms
# 7:	learn: 0.3784646	total: 72.6ms	remaining: 18.1ms
# 8:	learn: 0.3565976	total: 72.9ms	remaining: 8.1ms
# 4:	learn: 0.4667699	total: 74.7ms	remaining: 74.7ms
# 2:	learn: 0.5212477	total: 75ms	remaining: 175ms
# 9:	learn: 0.3334821	total: 73.3ms	remaining: 0us
# 5:	learn: 0.4294044	total: 75.3ms	remaining: 50.2ms
# 3:	learn: 0.4693020	total: 75.9ms	remaining: 114ms
# 6:	learn: 0.4030381	total: 76ms	remaining: 32.6ms
# 4:	learn: 0.4363264	total: 76.4ms	remaining: 76.4ms
# 5:	learn: 0.4255326	total: 76.9ms	remaining: 51.3ms
# 7:	learn: 0.3781039	total: 76.5ms	remaining: 19.1ms
# 0:	learn: 0.5907620	total: 65.4ms	remaining: 589ms
# 0:	learn: 0.5920560	total: 505us	remaining: 4.55ms
# 8:	learn: 0.3475154	total: 77ms	remaining: 8.56ms
# 6:	learn: 0.3980453	total: 77.3ms	remaining: 33.1ms
# 1:	learn: 0.5532132	total: 967us	remaining: 3.87ms
# 7:	learn: 0.3729976	total: 77.8ms	remaining: 19.4ms
# 9:	learn: 0.3310872	total: 77.5ms	remaining: 0us
# 2:	learn: 0.4999880	total: 1.42ms	remaining: 3.31ms
# 1:	learn: 0.5414902	total: 66.4ms	remaining: 266ms
# 8:	learn: 0.3545548	total: 78.2ms	remaining: 8.69ms
# 3:	learn: 0.4695533	total: 1.83ms	remaining: 2.74ms
# 2:	learn: 0.5041307	total: 66.8ms	remaining: 156ms
# 9:	learn: 0.3308117	total: 78.7ms	remaining: 0us
# 3:	learn: 0.4845244	total: 67.5ms	remaining: 101ms
# 4:	learn: 0.4378551	total: 68ms	remaining: 68ms
# 5:	learn: 0.4284876	total: 68.5ms	remaining: 45.6ms
# 4:	learn: 0.4421948	total: 3.94ms	remaining: 3.94ms
# 6:	learn: 0.3980993	total: 68.9ms	remaining: 29.5ms
# 5:	learn: 0.4209472	total: 4.42ms	remaining: 2.95ms
# 7:	learn: 0.3746890	total: 69.4ms	remaining: 17.3ms
# 8:	learn: 0.3521182	total: 69.8ms	remaining: 7.76ms
# 6:	learn: 0.3987447	total: 4.97ms	remaining: 2.13ms
# 9:	learn: 0.3230941	total: 70.3ms	remaining: 0us
# 7:	learn: 0.3757739	total: 5.71ms	remaining: 1.43ms
# 8:	learn: 0.3512607	total: 6.25ms	remaining: 694us
# 9:	learn: 0.3234114	total: 6.7ms	remaining: 0us
# 0:	learn: 0.5758506	total: 500us	remaining: 4.51ms
# 1:	learn: 0.5127536	total: 942us	remaining: 3.77ms
# 2:	learn: 0.4800014	total: 1.39ms	remaining: 3.23ms
# 3:	learn: 0.4583628	total: 1.84ms	remaining: 2.76ms
# 4:	learn: 0.4219830	total: 2.28ms	remaining: 2.28ms
# 5:	learn: 0.3941147	total: 2.74ms	remaining: 1.82ms
# 6:	learn: 0.3650579	total: 3.19ms	remaining: 1.37ms
# 7:	learn: 0.3495647	total: 3.59ms	remaining: 898us
# 0:	learn: 0.5956111	total: 437us	remaining: 3.94ms
# 8:	learn: 0.3348508	total: 4.06ms	remaining: 450us
# 9:	learn: 0.3212525	total: 4.4ms	remaining: 0us
# 1:	learn: 0.5382634	total: 904us	remaining: 3.62ms
# 2:	learn: 0.5021270	total: 1.25ms	remaining: 2.92ms
# 3:	learn: 0.4536479	total: 1.71ms	remaining: 2.57ms
# 4:	learn: 0.4229083	total: 2.17ms	remaining: 2.17ms
# 5:	learn: 0.3889270	total: 2.62ms	remaining: 1.75ms
# 6:	learn: 0.3680216	total: 3.06ms	remaining: 1.31ms
# 0:	learn: 0.5974131	total: 424us	remaining: 3.82ms
# 7:	learn: 0.3405258	total: 3.53ms	remaining: 882us
# 1:	learn: 0.5298551	total: 890us	remaining: 3.56ms
# 8:	learn: 0.3228834	total: 3.99ms	remaining: 443us
# 2:	learn: 0.4826940	total: 1.34ms	remaining: 3.13ms
# 3:	learn: 0.4248204	total: 1.7ms	remaining: 2.55ms
# 9:	learn: 0.3031041	total: 4.46ms	remaining: 0us
# 4:	learn: 0.3791833	total: 2.14ms	remaining: 2.14ms
# 0:	learn: 0.5842548	total: 523us	remaining: 4.71ms
# 5:	learn: 0.3660615	total: 2.59ms	remaining: 1.73ms
# 1:	learn: 0.5323464	total: 1ms	remaining: 4ms
# 6:	learn: 0.3457848	total: 3.08ms	remaining: 1.32ms
# 2:	learn: 0.4815858	total: 1.47ms	remaining: 3.42ms
# 3:	learn: 0.4539019	total: 1.91ms	remaining: 2.87ms
# 7:	learn: 0.3281431	total: 3.85ms	remaining: 961us
# 0:	learn: 0.5904350	total: 63.3ms	remaining: 570ms
# 4:	learn: 0.4296885	total: 2.36ms	remaining: 2.36ms
# 1:	learn: 0.5421501	total: 63.9ms	remaining: 256ms
# 5:	learn: 0.4107580	total: 2.83ms	remaining: 1.88ms
# 8:	learn: 0.3101108	total: 4.71ms	remaining: 523us
# 6:	learn: 0.3828862	total: 3.27ms	remaining: 1.4ms
# 2:	learn: 0.5064308	total: 64.5ms	remaining: 150ms
# 0:	learn: 0.5798559	total: 494us	remaining: 4.45ms
# 9:	learn: 0.2967799	total: 5.56ms	remaining: 0us
# 0:	learn: 0.5810561	total: 520us	remaining: 4.68ms
# 1:	learn: 0.5341535	total: 948us	remaining: 3.79ms
# 7:	learn: 0.3665674	total: 3.74ms	remaining: 935us
# 3:	learn: 0.4700539	total: 65.3ms	remaining: 98ms
# 8:	learn: 0.3378831	total: 4.19ms	remaining: 465us
# 2:	learn: 0.4926427	total: 1.39ms	remaining: 3.24ms
# 1:	learn: 0.5394267	total: 986us	remaining: 3.95ms
# 9:	learn: 0.3227437	total: 4.65ms	remaining: 0us
# 2:	learn: 0.4935648	total: 1.44ms	remaining: 3.37ms
# 4:	learn: 0.4145691	total: 65.9ms	remaining: 65.9ms
# 3:	learn: 0.4600913	total: 1.95ms	remaining: 2.93ms
# 0:	learn: 0.5769022	total: 453us	remaining: 4.08ms
# 5:	learn: 0.3966378	total: 66.4ms	remaining: 44.2ms
# 3:	learn: 0.4633425	total: 1.92ms	remaining: 2.89ms
# 4:	learn: 0.4307017	total: 2.42ms	remaining: 2.42ms
# 1:	learn: 0.5369773	total: 898us	remaining: 3.59ms
# 6:	learn: 0.3766824	total: 66.8ms	remaining: 28.6ms
# 5:	learn: 0.4065615	total: 2.89ms	remaining: 1.92ms
# 4:	learn: 0.4299765	total: 2.5ms	remaining: 2.5ms
# 0:	learn: 0.5852356	total: 476us	remaining: 4.29ms
# 7:	learn: 0.3536942	total: 67.3ms	remaining: 16.8ms
# 6:	learn: 0.3919665	total: 3.34ms	remaining: 1.43ms
# 5:	learn: 0.4124282	total: 2.96ms	remaining: 1.98ms
# 2:	learn: 0.4945894	total: 1.84ms	remaining: 4.29ms
# 1:	learn: 0.5329603	total: 926us	remaining: 3.71ms
# 7:	learn: 0.3614296	total: 3.79ms	remaining: 947us
# 6:	learn: 0.3904825	total: 3.4ms	remaining: 1.46ms
# 8:	learn: 0.3291589	total: 68ms	remaining: 7.55ms
# 2:	learn: 0.4870388	total: 1.39ms	remaining: 3.25ms
# 8:	learn: 0.3442216	total: 4.26ms	remaining: 473us
# 7:	learn: 0.3733949	total: 3.86ms	remaining: 965us
# 3:	learn: 0.4646000	total: 2.7ms	remaining: 4.05ms
# 9:	learn: 0.3287031	total: 4.61ms	remaining: 0us
# 3:	learn: 0.4625610	total: 1.84ms	remaining: 2.77ms
# 9:	learn: 0.3030464	total: 68.6ms	remaining: 0us
# 4:	learn: 0.4317251	total: 3.17ms	remaining: 3.17ms
# 8:	learn: 0.3510219	total: 4.33ms	remaining: 481us
# 4:	learn: 0.4362276	total: 2.36ms	remaining: 2.36ms
# 5:	learn: 0.4131169	total: 3.61ms	remaining: 2.41ms
# 9:	learn: 0.3347036	total: 4.84ms	remaining: 0us
# 0:	learn: 0.5880068	total: 57.4ms	remaining: 517ms
# 5:	learn: 0.3996330	total: 2.81ms	remaining: 1.88ms
# 6:	learn: 0.3960004	total: 4.23ms	remaining: 1.81ms
# 6:	learn: 0.3827909	total: 3.26ms	remaining: 1.4ms
# 1:	learn: 0.5426133	total: 58ms	remaining: 232ms
# 7:	learn: 0.3683382	total: 4.69ms	remaining: 1.17ms
# 7:	learn: 0.3561041	total: 3.72ms	remaining: 929us
# 2:	learn: 0.5066496	total: 58.4ms	remaining: 136ms
# 8:	learn: 0.3441685	total: 5.13ms	remaining: 569us
# 8:	learn: 0.3358115	total: 4.16ms	remaining: 461us
# 3:	learn: 0.4674150	total: 58.9ms	remaining: 88.3ms
# 9:	learn: 0.3290846	total: 5.59ms	remaining: 0us
# 9:	learn: 0.3217276	total: 4.62ms	remaining: 0us
# 4:	learn: 0.4330149	total: 59.4ms	remaining: 59.4ms
# 5:	learn: 0.4082012	total: 60ms	remaining: 40ms
# 6:	learn: 0.3941098	total: 60.5ms	remaining: 25.9ms
# 7:	learn: 0.3747290	total: 61ms	remaining: 15.2ms
# 8:	learn: 0.3472859	total: 61.4ms	remaining: 6.82ms
# 0:	learn: 0.6007125	total: 56.1ms	remaining: 505ms
# 9:	learn: 0.3161486	total: 61.9ms	remaining: 0us
# 1:	learn: 0.5426701	total: 56.6ms	remaining: 226ms
# 0:	learn: 0.6048669	total: 59.5ms	remaining: 535ms
# 2:	learn: 0.5103987	total: 57.1ms	remaining: 133ms
# 3:	learn: 0.4503204	total: 57.5ms	remaining: 86.2ms
# 1:	learn: 0.5402369	total: 60.1ms	remaining: 240ms
# 4:	learn: 0.4137622	total: 57.9ms	remaining: 57.9ms
# 2:	learn: 0.5092977	total: 60.6ms	remaining: 141ms
# 0:	learn: 0.5961496	total: 546us	remaining: 4.92ms
# 5:	learn: 0.3940370	total: 58.4ms	remaining: 38.9ms
# 3:	learn: 0.4766934	total: 61ms	remaining: 91.5ms
# 1:	learn: 0.5372642	total: 1ms	remaining: 4ms
# 4:	learn: 0.4513967	total: 61.5ms	remaining: 61.5ms
# 6:	learn: 0.3714608	total: 58.8ms	remaining: 25.2ms
# 2:	learn: 0.5087060	total: 1.44ms	remaining: 3.36ms
# 0:	learn: 0.6018074	total: 55.7ms	remaining: 501ms
# 7:	learn: 0.3455013	total: 59.3ms	remaining: 14.8ms
# 5:	learn: 0.4345229	total: 61.9ms	remaining: 41.3ms
# 3:	learn: 0.4707440	total: 1.9ms	remaining: 2.84ms
# 1:	learn: 0.5419310	total: 56.5ms	remaining: 226ms
# 8:	learn: 0.3272636	total: 59.7ms	remaining: 6.63ms
# 6:	learn: 0.4093880	total: 62.4ms	remaining: 26.7ms
# 4:	learn: 0.4147593	total: 2.34ms	remaining: 2.34ms
# 9:	learn: 0.3057712	total: 60.2ms	remaining: 0us
# 5:	learn: 0.3801374	total: 2.77ms	remaining: 1.85ms
# 7:	learn: 0.3862552	total: 62.8ms	remaining: 15.7ms
# 2:	learn: 0.5021421	total: 57.3ms	remaining: 134ms
# 8:	learn: 0.3658959	total: 63.3ms	remaining: 7.03ms
# 9:	learn: 0.3408119	total: 63.6ms	remaining: 0us
# 6:	learn: 0.3602146	total: 3.7ms	remaining: 1.58ms
# 3:	learn: 0.4827654	total: 58.1ms	remaining: 87.2ms
# 7:	learn: 0.3373823	total: 4.17ms	remaining: 1.04ms
# 8:	learn: 0.3202558	total: 4.62ms	remaining: 512us
# 4:	learn: 0.4428817	total: 59ms	remaining: 59ms
# 9:	learn: 0.3053704	total: 5.07ms	remaining: 0us
# 5:	learn: 0.4102439	total: 59.9ms	remaining: 39.9ms
# 6:	learn: 0.3805240	total: 60.7ms	remaining: 26ms
# 7:	learn: 0.3596884	total: 61.5ms	remaining: 15.4ms
# 8:	learn: 0.3321450	total: 62.4ms	remaining: 6.93ms
# 9:	learn: 0.3151595	total: 63.2ms	remaining: 0us
# 0:	learn: 0.6000761	total: 502us	remaining: 4.52ms
# 1:	learn: 0.5570461	total: 1.01ms	remaining: 4.03ms
# 2:	learn: 0.5065780	total: 1.58ms	remaining: 3.7ms
# 3:	learn: 0.4764496	total: 1.91ms	remaining: 2.86ms
# 4:	learn: 0.4437475	total: 2.26ms	remaining: 2.26ms
# 0:	learn: 0.5932911	total: 429us	remaining: 3.87ms
# 0:	learn: 0.5793453	total: 499us	remaining: 4.5ms
# 5:	learn: 0.4033530	total: 2.7ms	remaining: 1.8ms
# 1:	learn: 0.5376862	total: 879us	remaining: 3.52ms
# 1:	learn: 0.5189567	total: 942us	remaining: 3.77ms
# 6:	learn: 0.3698554	total: 3.14ms	remaining: 1.34ms
# 2:	learn: 0.5076260	total: 1.33ms	remaining: 3.11ms
# 2:	learn: 0.4730637	total: 1.39ms	remaining: 3.23ms
# 7:	learn: 0.3474007	total: 3.58ms	remaining: 895us
# 3:	learn: 0.4568916	total: 1.69ms	remaining: 2.54ms
# 3:	learn: 0.4816875	total: 1.79ms	remaining: 2.68ms
# 8:	learn: 0.3360573	total: 4.03ms	remaining: 448us
# 4:	learn: 0.4275617	total: 2.13ms	remaining: 2.13ms
# 4:	learn: 0.4458591	total: 2.24ms	remaining: 2.24ms
# 9:	learn: 0.3122253	total: 4.49ms	remaining: 0us
# 5:	learn: 0.4079795	total: 2.59ms	remaining: 1.73ms
# 5:	learn: 0.4134435	total: 2.7ms	remaining: 1.8ms
# 6:	learn: 0.3929667	total: 3.03ms	remaining: 1.3ms
# 6:	learn: 0.3948018	total: 3.14ms	remaining: 1.35ms
# 7:	learn: 0.3771734	total: 3.47ms	remaining: 867us
# 7:	learn: 0.3694717	total: 3.6ms	remaining: 898us
# 8:	learn: 0.3595410	total: 3.78ms	remaining: 419us
# 8:	learn: 0.3382122	total: 4.05ms	remaining: 449us
# 9:	learn: 0.3379902	total: 4.17ms	remaining: 0us
# 9:	learn: 0.3121378	total: 4.49ms	remaining: 0us
# 0.80, 0.04

# %%
results_to_show
# Out:
#        No composition  Dummy  Bagging  Bagging_mf  AdaBoost
# DTC              0.79   0.80     0.86        0.88      0.79
# DTC-1            0.68   0.68     0.68        0.69      0.81
# LR               0.81   0.81     0.81        0.81      0.80
# SVC              0.94   0.94     0.94        0.94      0.50

# %%
f"{sklearn_gboost:.2f}, {xg_boost:.2f}, {lg_boost:.2f}, {сat_boost:.2f}"
# Out:
# '0.90, 0.92, 0.95, 0.80'

# %% [markdown]
# ### Random forest

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

# %%
data = load_wine()
X = data['data']
Y = data['target']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, 
                                                    test_size=30, 
                                                    random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

model = RandomForestClassifier(n_estimators=6, max_depth=2, random_state=0)
model.fit(X_train, Y_train)

print(f"train_score = {model.score(X_train, Y_train):.2f}, test_score = {model.score(X_test, Y_test):.2f}")
print(classification_report(Y_test, model.predict(X_test), digits=2))
# Out:
# train_score = 0.98, test_score = 0.97
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      0.93      0.97        15
#            2       0.86      1.00      0.92         6
#
#     accuracy                           0.97        30
#    macro avg       0.95      0.98      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# #### Dependence on the number of trees

# %%
models = []
scores_train = []
scores_test = []
n_estimators = list(range(1, 20))
for estimators in n_estimators:
    model = RandomForestClassifier(n_estimators=estimators, random_state=0)
    model.fit(X_train, Y_train)
    models.append(model)
    scores_test.append(model.score(X_test, Y_test))
    scores_train.append(model.score(X_train, Y_train))

# %%
import matplotlib.pyplot as plt

plt.plot(n_estimators, scores_train, label='train')
plt.plot(n_estimators, scores_test, label='test')

plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# #### Dependence on the number of features

# %%
models = []
scores_train = []
scores_test = []
max_features = list(range(1, 13))
for features in max_features:
    model = RandomForestClassifier(n_estimators=6, 
                                   max_features=features, random_state=0)
    model.fit(X_train, Y_train)
    models.append(model)
    scores_test.append(model.score(X_test, Y_test))
    scores_train.append(model.score(X_train, Y_train))

# %%
plt.plot(max_features, scores_train, label='train')
plt.plot(max_features, scores_test, label='test')

plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# #### Dependence on tree depth

# %%
models = []
scores_train = []
scores_test = []
current_depth = []
max_depth = list(range(1, 10))
for depth in max_depth:
    model = RandomForestClassifier(n_estimators=6,
        max_depth=depth, random_state=0)
    model.fit(X_train, Y_train)
    models.append(model)
    scores_test.append(model.score(X_test, Y_test))
    scores_train.append(model.score(X_train, Y_train))
    current_depth.append(model.estimators_[0].get_depth()/depth)

# %%
plt.plot(max_depth, scores_train, label='train')
plt.plot(max_depth, scores_test, label='test')
plt.plot(max_depth, current_depth, label='real depth')

plt.legend(loc='best')
plt.grid()
plt.show()

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=42)

# %%
acc_mean, acc_std = eval_classifier(RandomForestClassifier(n_estimators=10, max_depth=5, max_features=3, random_state=0))

print(f"{acc_mean:.2f}, {acc_std:.2f}")
# Out:
# 0.83, 0.04
